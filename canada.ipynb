# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly.express as px

# %%
data = {
    'Category': ['Electronics', 'Electronics', 'Electronics', 
                 'Furniture', 'Furniture', 'Furniture', 
                 'Clothing', 'Clothing', 'Clothing'],
    'Subcategory': ['Laptops', 'Smartphones', 'Tablets', 
                    'Chairs', 'Tables', 'Sofas', 
                    'Men', 'Women', 'Kids'],
    'Sales': [120000, 80000, 30000, 
              50000, 40000, 20000, 
              70000, 90000, 40000]
}

# %%
df = pd.DataFrame(data)
df
# Out:
#       Category  Subcategory   Sales
# 0  Electronics      Laptops  120000
# 1  Electronics  Smartphones   80000
# 2  Electronics      Tablets   30000
# 3    Furniture       Chairs   50000
# 4    Furniture       Tables   40000
# 5    Furniture        Sofas   20000
# 6     Clothing          Men   70000
# 7     Clothing        Women   90000
# 8     Clothing         Kids   40000

# %%
fig = px.treemap(
    df,
    path=['Category', 'Subcategory'],
    values='Sales',
    title='Sales Data Treemap'
)
fig.show()

# %%
data = pd.read_csv("employee_data.csv")
data
# Out:
#     EmployeeID    FirstName   LastName  DepartmentID  Salary    HireDate  \
# 0         1000         John      Smith             1   55000  2015-01-01
# 1         1001        Sarah    Johnson             2   65000  2015-01-02
# 2         1002        David      Brown             1   60000  2015-01-03
# 3         1003         Emma     Taylor             3   72000  2015-01-04
# 4         1004      Michael   Anderson             2   58000  2015-01-05
# 5         1005       Olivia     Thomas             4   68000  2015-01-06
# 6         1006       Daniel    Jackson             1   59000  2015-01-07
# 7         1007       Sophia      White             3   75000  2015-01-08
# 8         1008        James     Harris             2   63000  2015-01-09
# 9         1009          Ava     Martin             4   70000  2015-01-10
# 10        1010       Robert   Thompson             3   62000  2015-01-11
# 11        1011          Mia     Garcia             1   54000  2015-01-12
# 12        1012      William   Martinez             4   80000  2015-01-13
# 13        1013     Isabella   Robinson             2   66000  2015-01-14
# 14        1014       Joseph      Clark             3   61000  2015-01-15
# 15        1015        Emily  Rodriguez             4   69000  2015-01-16
# 16        1016      Charles      Lewis             1   57000  2015-01-17
# 17        1017       Amelia        Lee             2   64000  2015-01-18
# 18        1018       Thomas     Walker             3   71000  2015-01-19
# 19        1019       Harper       Hall             4   73000  2015-01-20
# 20        1020        Henry      Allen             1   56000  2015-01-21
# 21        1021       Evelyn      Young             2   65500  2015-01-22
# 22        1022      Matthew       King             3   70500  2015-01-23
# 23        1023      Abigail     Wright             4   74000  2015-01-24
# 24        1024  Christopher      Scott             1   58500  2015-01-25
# 25        1025         Ella      Green             2   67500  2015-01-26
# 26        1026       Andrew      Baker             3   69500  2015-01-27
# 27        1027        Grace      Adams             4   77000  2015-01-28
# 28        1028         Jack     Nelson             2   66000  2015-01-29
# 29        1029        Chloe     Carter             3   71500  2015-01-30
#
#       JobTitle
# 0      Analyst
# 1      Manager
# 2      Analyst
# 3     Engineer
# 4   Technician
# 5     Engineer
# 6      Analyst
# 7      Manager
# 8     Engineer
# 9   Technician
# 10     Manager
# 11     Analyst
# 12    Director
# 13     Manager
# 14     Analyst
# 15    Engineer
# 16     Analyst
# 17     Manager
# 18    Engineer
# 19  Technician
# 20     Analyst
# 21     Manager
# 22    Engineer
# 23  Technician
# 24     Analyst
# 25    Engineer
# 26     Manager
# 27  Technician
# 28    Engineer
# 29     Analyst
