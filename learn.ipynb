# %%
# %pip install randomuser
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5128 sha256=5f118aadddca7b9d0f0a7d0ce53b4a560c09b5739c5c56aeba46aee5e71d8475
#   Stored in directory: c:\users\jdarl\appdata\local\pip\cache\wheels\be\62\c8\71e1b48f4758ea5b78af7595d87178f628cde315a3326610ee
# Successfully built randomuser
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from randomuser import RandomUser

# %%
r = RandomUser()
r

# %%
users = r.generate_users(1000)

# %%
users

# %%
name = r.get_full_name()

# %%
for city in users:
    print(city.get_city())
# Out:
# Kastamonu
# Wells
# Meterik
# Vitória de Santo Antão
# Zaragoza
# Tourcoing
# Versailles
# Tuam
# Rancho Cucamonga
# Clonmel
# Dublin
# Leppävirta
# Nevşehir
# Quarten
# Artvin
# Nowra
# Toholampi
# Kastamonu
# St. George
# Waco
# San Sebastián de Los Reyes
# Palmerston North
# Norderney
# Geithus
# Karaman
# Angers
# Leixlip
# Pozuelo de Alarcón
# Oulunsalo
# Donneloye
# Paltamo
# Shannon
# Bayburt
# ساری
# Hospitalet de Llobregat
# بندرعباس
# Alcalá de Henares
# Masterton
# Stevenage
# Perpignan
# Roosteren
# Newbridge
# Hampstead
# Montpellier
# Juelsminde
# Santander
# Caen
# Farmers Branch
# Hortolândia
# Tralee
# Elche
# Corban
# Meldal
# Joutsa
# Maynooth
# Santa Cruz de Tenerife
# Dillenburg
# Dungarvan
# Zwönitz
# Edinburgh
# Fauquier
# Roslev
# São Luís
# Vaala
# Malahide
# Castellón de la Plana
# St. George
# Raahe
# Wellington
# Napier
# Gjerlev
# Perpignan
# دزفول
# Isparta
# Swansea
# Naas
# Nampa
# Plymouth
# Kalgoorlie
# Aix-En-Provence
# Nieuwe Krim
# Goedereede
# ...

# %%
for user in users:
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/96.jpg
# https://randomuser.me/api/portraits/men/83.jpg
# https://randomuser.me/api/portraits/men/29.jpg
# https://randomuser.me/api/portraits/women/94.jpg
# https://randomuser.me/api/portraits/women/73.jpg
# https://randomuser.me/api/portraits/men/72.jpg
# https://randomuser.me/api/portraits/men/47.jpg
# https://randomuser.me/api/portraits/women/44.jpg
# https://randomuser.me/api/portraits/women/16.jpg
# https://randomuser.me/api/portraits/women/50.jpg
# https://randomuser.me/api/portraits/women/25.jpg
# https://randomuser.me/api/portraits/men/56.jpg
# https://randomuser.me/api/portraits/men/68.jpg
# https://randomuser.me/api/portraits/women/0.jpg
# https://randomuser.me/api/portraits/women/74.jpg
# https://randomuser.me/api/portraits/men/91.jpg
# https://randomuser.me/api/portraits/men/82.jpg
# https://randomuser.me/api/portraits/men/32.jpg
# https://randomuser.me/api/portraits/women/49.jpg
# https://randomuser.me/api/portraits/men/81.jpg
# ...

# %%
def getting_users():
    users = []

    for user in RandomUser.generate_users(10):
       # users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
        users.append({"Name": user.get_full_name(), "Gender": user.get_gender(), "City": user.get_city(), "State": user.get_state(), "Email": user.get_email(), "Phone": user.get_phone(), "DOB": user.get_dob(), "Picture": user.get_picture()})

    return pd.DataFrame(users)

# %%
getting_users()
# Out:
#               Name  Gender            City                  State  \
# 0    Robert Fuller    male         Bunbury      Western Australia
# 1      Borja Parra    male      Pontevedra        Castilla y León
# 2      Vital Alves    male            Bagé                Alagoas
# 3     Linnea Wuori  female       Virolahti  Southern Ostrobothnia
# 4       آرتين گلشن    male             کرج                کردستان
# 5    Marion Dubois  female            Nice         Seine-et-Marne
# 6         Zoe Wang  female          Napier             West Coast
# 7  Rosário Martins    male  Angra dos Reis    Rio Grande do Norte
# 8   Peppi Lehtinen  female        Pirkkala                  Åland
# 9     Emil Mattila    male         Keitele            Kymenlaakso
#
#                          Email           Phone                       DOB  \
# 0    robert.fuller@example.com    00-7053-2371  1955-01-15T18:54:37.497Z
# 1      borja.parra@example.com     985-336-476  1988-10-23T21:58:47.272Z
# ...

# %%
import requests
import json

# %%
data = requests.get("https://fruityvice.com/api/fruit/all")

# %%
results = json.loads(data.text)

# %%
pd.DataFrame(results)
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
banana = df2.loc[df2["name"] == 'Banana']
(banana.iloc[0]['family']) , (banana.iloc[0]['genus'])
# Out:
# ('Musaceae', 'Musa')

# %%
data2 = requests.get("https://official-joke-api.appspot.com/jokes/ten")

# %%
results2 = json.loads(data2.text)

# %%
df3 = pd.DataFrame(results2)
df3.drop(columns=["type", "id"], inplace=True)
df3
# Out:
#                                                setup  \
# 0  What do you call a fashionable lawn statue wit...
# 1  Do you know where you can get chicken broth in...
# 2                                   What time is it?
# 3  What do you call a droid that takes the long w...
# 4  Did you hear about the runner who was criticized?
# 5             Why do birds fly south for the winter?
# 6  A SQL query walks into a bar, walks up to two ...
# 7                 How do you organize a space party?
# 8           Why did the coffee file a police report?
# 9                   Why did the barber win the race?
#
#                             punchline
# 0                       A metro-gnome
# 1                   The stock market.
# 2  I don't know... it keeps changing.
# 3                          R2 detour.
# 4           He just took it in stride
# 5       Because it's too far to walk.
# 6                   'Can I join you?'
# 7                         You planet.
# ...
